# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de las coordenadas
data = {
    "Perfil": ["Perfil", "PerfilSGC"],
    "Costado NW (X)": [-77.725, -77.700],
    "Costado NW (Y)": [1.118, 1.123],
    "Costado SE (X)": [-77.672, -77.597],
    "Costado SE (Y)": [0.988, 1.064],
}

# Crear un DataFrame
df = pd.DataFrame(data)
df.to_csv("perfil_coordenadas.csv", index=False)  # Guardar como CSV

# %%
import pandas as pd

df = pd.read_csv("perfil_coordenadas.csv")
print(df)
# Out:
#       Perfil  Costado NW (X)  Costado NW (Y)  Costado SE (X)  Costado SE (Y)
# 0     Perfil         -77.725           1.118         -77.672           0.988
# 1  PerfilSGC         -77.700           1.123         -77.597           1.064
